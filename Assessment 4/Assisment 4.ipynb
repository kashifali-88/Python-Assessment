# %%
# Q6: Calculate the sum of three numbers

num = input("Enter Three Numers: ")

total_sum = int(num[0])+int(num[1])+int(num[2])

print("The sum of the three numbers is:", total_sum)
# Out:
# Enter Three Numers:  456
# The sum of the three numbers is: 15

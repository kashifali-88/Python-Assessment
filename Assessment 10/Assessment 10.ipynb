# %% [markdown]
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ## Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom.

# %%
import pandas as pd

# %%
ecom = pd.read_csv("C:/Users/k H a N/PSEB/Ecommerce Purchases.csv")

# %% [markdown]
# ## Check the head of the DataFrame.

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# ## How many rows and columns are there?

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ## What is the average Purchase Price?

# %%
average_purchase = ecom["Purchase Price"].mean()
print("The average Purchase Price", average_purchase)
# Out:
# The average Purchase Price 50.347302

# %% [markdown]
# ## What were the highest and lowest purchase prices?

# %%
highest_purchase = ecom["Purchase Price"].max()
print("The highest Purchase Price", highest_purchase)
# Out:
# The highest Purchase Price 99.99

# %%
lowest_purchase = ecom["Purchase Price"].min()
print("The Lowest Purchase", lowest_purchase)
# Out:
# The Lowest Purchase 0.0

# %% [markdown]
# ## How many people have English 'en' as their Language of choice on the website?

# %%
num_english_users = (ecom['Language'] == 'en').sum()
print(num_english_users)
# Out:
# 1098

# %% [markdown]
# ## How many people have the job title of "Lawyer" ?

# %%
num_lawyer = (ecom['Job'] == 'Lawyer').sum()
print(num_lawyer)
# Out:
# 30

# %% [markdown]
# ## How many people made the purchase during the AM and how many people made the purchase during PM ?

# %%
purchase_counts = ecom['AM or PM'].value_counts()

num_am_purchases = purchase_counts['AM']
num_pm_purchases = purchase_counts['PM']

print("PM:", num_pm_purchases)
print("AM:", num_am_purchases)
# Out:
# PM: 5068
# AM: 4932

# %% [markdown]
# ## What are the 5 most common Job Titles?

# %%
ecom["Job"].value_counts().nlargest(5)
# Out:
# Job
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
# Name: count, dtype: int64

# %% [markdown]
# ## Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?

# %%
result = ecom[ecom['Credit Card'] == 4926535242672853]['Email']

if not result.empty:
    email = result.iloc[0]
    print(email)
else:
    print("No user found with that Credit Card number.")
# Out:
# bondellen@williams-garza.com

# %% [markdown]
# ## What is the email of the person with the following Credit Card Number: 4926535242672853

# %%
# Condition 1: Card Provider is 'American Express'
# Condition 2: Purchase Price is greater than 95
amex_high_purchase = ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)]

# Count the number of rows that match
count = len(amex_high_purchase)
print(f"Number of people: {count}")
# Out:
# Number of people: 39

# %% [markdown]
# ## How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?

# %%
num_people = ((ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)).sum()

print(num_people, "Peoples have American Express Credit Card Provider and made a Purchase above $95")
# Out:
# 39 Peoples have American Express Credit Card Provider and made a Purchase above $95

# %% [markdown]
# ## Hard: How many people have a credit card that expires in 2025?

# %%
ecom['CC Exp Year'] = pd.to_datetime(ecom['CC Exp Date'], format='%m/%y').dt.year

# Count the occurrences where the year is '2025'
num_people = (ecom['CC Exp Year'] == 2025).sum()

num_people
# Out:
# np.int64(1171)

# %% [markdown]
# ## Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)

# %%
ecom['Email Domain'] = ecom['Email'].str.split('@').str[1]

# Count the occurrences of each email domain
top_email_providers = ecom['Email Domain'].value_counts().head(5)

top_email_providers
# Out:
# Email Domain
# gmail.com      3474
# yahoo.com      2538
# hotmail.com    1541
# outlook.com     765
# aol.com         496
# Name: count, dtype: int64

# %% [markdown]
# # Great Job!

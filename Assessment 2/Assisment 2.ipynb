# %%
# Q1: Print a welcome message
print("Hello, everyone! I am learning Python. 😄")
# Out:
# Hello, everyone! I am learning Python. 😄

# %%
# Task 2: Declaring Variables

# Declaring variables
name = "Kashif Ullah"          # string
age = 22                 # integer
favorite_animal = "Cat"  # string

# Printing variables one by one
print("Name:", name)
print("Age:", age)
print("Favorite Animal:", favorite_animal)

# %%
# Task 3: Combining Variables in a Message
name= "kashif Ullah"
age = 22
favorite_animal= "cat"
# Using variables from Task 
print("My name is", name, ", I am", age, "years old, and I love", favorite_animal + "s!")
# Out:
# My name is kashif Ullah , I am 22 years old, and I love cats!

# %%
# Task 4: Playing with Different Data Types

# Declaring variables of different types
favorite_movie = "Inception"   # string
birth_year = 2003              # integer
snack_price = 55              # integer

# Printing each variable
print("Favorite Movie:", favorite_movie)
print("Birth Year:", birth_year)
print("Price of Snack:", snack_price)
# Out:
# Favorite Movie: Inception
# Birth Year: 2003
# Price of Snack: 55

# %%
# Task 5: Your Favorite Hobby

hobby = "Watching Movies"
print("My favorite hobby is", hobby + ".")
# Out:
# My favorite hobby is Watching Movies.

# %%
# Extra Challenge: Adding two variables

a = 5
b = 7
c = a + b         # assigning sum of a and b

print("a =", a)
print("b =", b)
print("c =", c, )
# Out:
# a = 5
# b = 7
# c = 12
